# %% [markdown]
# ### Sentiment Analysis

# %%
import numpy as np   
import pandas as pd

# %%
dataset = pd.read_csv(r'C:\Users\Shri\Desktop\reviews.csv')

# %%
dataset.head()
# Out:
#                                         Product Name Brand Name   Price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    Rating                                            Reviews  Review Votes
# 0       5  I feel so LUCKY to have found this used (phone...           1.0
# 1       4  nice phone, nice up grade from my pantach revu...           0.0
# 2       5                                       Very pleased           0.0
# 3       4  It works good but it goes slow sometimes but i...           0.0
# 4       4  Great phone to replace my lost phone. The only...           0.0

# %%
dataset["is_bad_review"] = dataset["Rating"].apply(lambda x: 1 if x < 3 else 0)
dataset = dataset[["Reviews", "is_bad_review"]]
dataset.head()
# Out:
#                                              Reviews  is_bad_review
# 0  I feel so LUCKY to have found this used (phone...              0
# 1  nice phone, nice up grade from my pantach revu...              0
# 2                                       Very pleased              0
# 3  It works good but it goes slow sometimes but i...              0
# 4  Great phone to replace my lost phone. The only...              0

# %%
dataset = dataset.sample(frac = 0.1, replace = False, random_state=42)

# %%
dataset["Reviews"] = dataset["Reviews"].apply(lambda x: str(x).replace("No Negative", "").replace("No Positive", ""))

# %%
dataset.head()
# Out:
#                                                   Reviews  is_bad_review
# 54870   Defective phone. Works only for two days. Phon...              1
# 188521                                               Cool              0
# 137548                    Beautiful and excellent quality              0
# 24906   Gave 3 stars because it did not come with a ch...              1
# 131601  High resolution camera so you can zoom in afte...              1

# %%
from nltk.corpus import wordnet

# %%
def get_wordnet_pos(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('V'):
        return wordnet.VERB
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
import string
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer

# %%
def clean_text(text):
    
    text = text.lower()
    
    text = [word.strip(string.punctuation) for word in text.split(" ")]
    
    text = [word for word in text if not any(c.isdigit() for c in word)]
    
    stop = stopwords.words('english')
    text = [x for x in text if x not in stop]
    
    text = [t for t in text if len(t) > 0]
    
    pos_tags = pos_tag(text)
    
    text = [WordNetLemmatizer().lemmatize(t[0], get_wordnet_pos(t[1])) for t in pos_tags]
    
    text = [t for t in text if len(t) > 1]
    
    text = " ".join(text)
    return(text)

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
dataset["sentiments"] = dataset["Reviews"].apply(lambda x: sid.polarity_scores(x))
dataset = pd.concat([dataset.drop(['sentiments'], axis=1), dataset['sentiments'].apply(pd.Series)], axis=1)

# %%
dataset.head()
# Out:
#                                                   Reviews  is_bad_review  \
# 54870   Defective phone. Works only for two days. Phon...              1
# 188521                                               Cool              0
# 137548                    Beautiful and excellent quality              0
# 24906   Gave 3 stars because it did not come with a ch...              1
# 131601  High resolution camera so you can zoom in afte...              1
#
#           neg    neu    pos  compound
# 54870   0.137  0.801  0.062   -0.5106
# 188521  0.000  0.000  1.000    0.3182
# 137548  0.000  0.208  0.792    0.8225
# 24906   0.109  0.848  0.042   -0.5037
# 131601  0.000  0.939  0.061    0.5719

# %% [markdown]
# ### Exploratory Data Analysis

# %%
dataset["is_bad_review"].value_counts(normalize = True)
# Out:
# 0    0.764039
# 1    0.235961
# Name: is_bad_review, dtype: float64

# %%
# add number of characters column
dataset["nb_chars"] = dataset["Reviews"].apply(lambda x: len(x))

# add number of words column
dataset["nb_words"] = dataset["Reviews"].apply(lambda x: len(x.split(" ")))

# %%
dataset.head()
# Out:
#                                                   Reviews  is_bad_review  \
# 54870   Defective phone. Works only for two days. Phon...              1
# 188521                                               Cool              0
# 137548                    Beautiful and excellent quality              0
# 24906   Gave 3 stars because it did not come with a ch...              1
# 131601  High resolution camera so you can zoom in afte...              1
#
#           neg    neu    pos  compound  nb_chars  nb_words
# 54870   0.137  0.801  0.062   -0.5106       236        41
# 188521  0.000  0.000  1.000    0.3182         4         1
# 137548  0.000  0.208  0.792    0.8225        31         4
# 24906   0.109  0.848  0.042   -0.5037       329        64
# 131601  0.000  0.939  0.061    0.5719       328        58

# %%
dataset[dataset["nb_words"] >= 5].sort_values("pos", ascending = False)[["Reviews", "pos"]].head(10)
# Out:
#                                       Reviews    pos
# 74853    SUPER SUPER PERFECT! SUPER SUPER NEW  0.951
# 74456    SUPER SUPER PERFECT! SUPER SUPER NEW  0.951
# 280099       Work perfectly great fit. Thanks  0.932
# 123571               Excellent! I love it. :D  0.924
# 123920               Excellent! I love it. :D  0.924
# 123312               Excellent! I love it. :D  0.924
# 171933             Great watch - great gift -  0.917
# 284267             Great product - good value  0.904
# 20120   Great value & buy...highly recommend!  0.903
# 139070        excellent I recommend .. Thanks  0.901

# %%
dataset[dataset["nb_words"] >= 5].sort_values("neg", ascending = False)[["Reviews", "neg"]].head(10)
# Out:
#                                                   Reviews    neg
# 20731                Bad bad bad bad it was BLACKLISTEDDD  0.824
# 288658                                Wrong size - my bad  0.767
# 91157   don't buy this, it sucks. don't buy this, it s...  0.753
# 65228                         Worst seller and worst site  0.732
# 153482     No issues... no problems using internationally  0.703
# 15221                        Bad product bad battery life  0.700
# 17433                        Bad product bad battery life  0.700
# 118551            Horrible photo quality horrible service  0.700
# 191520                It was broken. Deeply disappointed.  0.684
# 236815                        This phone sucks really bad  0.677

# %%
import seaborn as sb
import matplotlib.pyplot as plt

for x in [0, 1]:
    subset = dataset[dataset['is_bad_review'] == x]
    
    # Draw the density plot
    if x == 0:
        label = "Good Reviews"
    else:
        label = "Bad Reviews"
    sb.distplot(subset['compound'], hist = False, label = label)

plt.show()
